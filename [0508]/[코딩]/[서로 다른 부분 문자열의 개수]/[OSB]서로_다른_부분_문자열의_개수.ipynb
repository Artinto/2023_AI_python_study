# %% [markdown]
# # 문제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 예제
# ![image.png](data:image/png;base64,...)

# %%
string = input()
string_set = set()
for i in range(len(string)):
  for v in range(len(string)-i):
    string_set.add(string[v:v+i+1]) # 모든 경우에 대해서 더함
print(len(string_set))
# Out:
# ababc
# 12

# %%
string_set
# Out:
# {'a', 'ab', 'aba', 'abab', 'ababc', 'abc', 'b', 'ba', 'bab', 'babc', 'bc', 'c'}
