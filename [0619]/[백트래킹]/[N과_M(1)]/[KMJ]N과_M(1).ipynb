# %% [markdown]
# # N과 M(1)

# %% [markdown]
# ## 문제, 입/출력
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 코드

# %%
# 백트래킹은 모든 가능한 경우의 수 중에서 특정한 조건을 만족하는 경우만 살펴보는 것
# 모든 경우의 수 = n개의 수 중 m개로 만들 수 있는 모든 수 출력
# 탈출 조건 = s와 m이 만드는

# %%
n, m = map(int, input().split())

s = []

def dfs():
    if len(s) == m:
        print(" ".join(map(str, s)))
        return

    # for 문으로 반복
    for i in range(1, n + 1):
        if i not in s:
            s.append(i)
            dfs()
            s.pop()

dfs()
# Out:
# 4 2
# 1 2
# 1 3
# 1 4
# 2 1
# 2 3
# 2 4
# 3 1
# 3 2
# 3 4
# 4 1
# 4 2
# 4 3

# %%
l = []
n = int(input())
for i in range(1,n+1):
  l.append(i)
print(l)
# Out:
# 8
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
n = int(input())
print(n)
# Out:
# 32
# 32
