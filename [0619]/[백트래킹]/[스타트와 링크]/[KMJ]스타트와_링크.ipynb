# %% [markdown]
# # 스타트와 링크

# %% [markdown]
# ## 문제, 입/출력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 코드

# %%
# 탈출 조건

n = int(input())
graph = [ list(map(int, input().split())) for _ in range(n) ]
visit = [ False for _ in range(n) ] # false로 된 방문 리스트 생성
min_value = N//2 * (N//2-1) * 100 # 매우 큰 값 (최소값 갱신할 변수)

def backTracking(depth, idx):
    global min_value
    if depth == n // 2: # 탈출조건 = 스타트팀이 완성되면, 팀을 2개로 나누기 때문에 절반만 있어도 됨
        power1, power2 = 0, 0
        for i in range(n):
            for j in range(n):
                if visit[i] and visit[j]: # true인 경우 스타트 팀
                    power1 += graph[i][j]
                elif not visit[i] and not visit[j]: # false인 경우 링크 팀
                    power2 += graph[i][j]
        min_value = min(min_value, abs(power1-power2)) # 최소값을 찾으면 min_value 갱신
        return

    for i in range(idx, n): # 스타트팀이 완성되지 못하면 백트래킹
        if not visit[i]:
            visit[i] = True
            backTracking(depth+1, i+1) # 같은 번호 중복을 막기위 idx+1로 재귀호출
            visit[i] = False
backTracking(0, 0)
print(min_value)
# Out:
# 6
# 0 1 2 3 4 5
# 1 0 2 3 4 5
# 1 2 0 3 4 5
# 1 2 3 0 4 5
# 1 2 3 4 0 5
# 1 2 3 4 5 0
# 2
