# %% [markdown]
# # 문제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 예제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 풀이
# * 나머지는 2이상, 소수의 특징 이용

# %%
NUM = int(input())
while True:
  if NUM == 1:
    break
  else:
    for i in range(2, NUM+1):
      if NUM % i ==0:
        NUM =  int(NUM/i)
        print(i)
        break
# Out:
# 9991
# 97
# 103
