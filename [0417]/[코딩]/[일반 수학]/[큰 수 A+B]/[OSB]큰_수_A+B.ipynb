# %% [markdown]
# # 문제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 예제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 풀이
# * 파이썬에서는 **arbitrary-precision** 특징이 있어서 overflow 현상이 발생하지 않는다.
#   * 특정값을 나타낼때 메모리가 부족하다면 메모리를 더 사용하는 특징.
#   * C언어의 int형은  **fixed_precision**이라 사용할 수 있는 메모리 수가 제한되어 있음.
#
#
#   ![image.png](data:image/png;base64,...)

# %%
a, b = map(int, input().split(" "))
print(a + b)
# Out:
# 9223372036854775807 9223372036854775808
# 18446744073709551615
