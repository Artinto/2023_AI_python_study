# %% [markdown]
# # 문제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 예제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 풀이
# * 초기 상태 $2*2$
# * 1번 $3*3$
# * 2번 $5*5$
# * $(한변의 수*2 - 1)$로 증가
#   * 2 -> 3 -> 5 -> 9 -> 17 -> 33...

# %%
num = int(input()) # 진행할 횟수
init = 2 # 초기 한변의 점 개수
for _ in range(num):
  init = 2*init - 1
print(init**2)
# Out:
# 5
# 1089
