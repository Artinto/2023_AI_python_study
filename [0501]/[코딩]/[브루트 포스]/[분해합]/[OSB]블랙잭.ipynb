# %% [markdown]
# # 문제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 예제
# ![image.png](data:image/png;base64,...)

# %%
# 입력 받기
N, M = map(int, input().split(" "))
Card = list(map(int, input().split()))

# 브루트 포스
# 카드 3가지를 뽑는 모든 경우의 수를 찾음.
sum = []
for c1 in range(len(Card)):
  if c1 > len(Card) - 3:
    break
  card1 = Card[c1]
  for c2 in range(c1+1, len(Card)-1):
      card2 = Card[c2]
      for c3 in range(c2+1, len(Card)):
          card3 = Card[c3]
          sum.append(card1 + card2 + card3)
# M에 가장 가까우면서 넘지않는 카드 출력
print(max([i for i in sum if i <= M ]))
# Out:
# 10 500
# 93 181 245 214 315 36 195 138 216 295
# 497

# %%
# 카드 3가지를 뽑는 모든 경우의 수를 찾음.
card1, card2, card3 = 0, 0, 0 
sum = []
for c1 in range(len(Card)):
  if c1 > len(Card) - 3:
    break
  card1 = Card[c1]
  for c2 in range(c1+1, len(Card)-1):
    card2 = Card[c2]
    for c3 in range(c2+1, len(Card)):
      card3 = Card[c3]
      sum.append(card1 + card2 + card3)
      print('첫번째 : ', card1, '두번째 : ', card2, '세번째 : ', card3)
print(sum)
# Out:
# 첫번째 :  5 두번째 :  6 세번째 :  7
# 첫번째 :  5 두번째 :  6 세번째 :  8
# 첫번째 :  5 두번째 :  6 세번째 :  9
# 첫번째 :  5 두번째 :  7 세번째 :  8
# 첫번째 :  5 두번째 :  7 세번째 :  9
# 첫번째 :  5 두번째 :  8 세번째 :  9
# 첫번째 :  6 두번째 :  7 세번째 :  8
# 첫번째 :  6 두번째 :  7 세번째 :  9
# 첫번째 :  6 두번째 :  8 세번째 :  9
# 첫번째 :  7 두번째 :  8 세번째 :  9
# [18, 19, 20, 20, 21, 22, 21, 22, 23, 24]

# %%
# M에 가장 가까우면서 넘지않는 카드
max([i for i in sum if i <= M ])
# Out:
# 21
